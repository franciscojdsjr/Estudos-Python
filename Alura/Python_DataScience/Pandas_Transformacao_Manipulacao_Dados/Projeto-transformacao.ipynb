# %%
import pandas as pd

# %%
dados_hospedagem = pd.read_json('dados_hospedagem.json')
moveis_disponiveis = pd.read_json('moveis_disponiveis.json')

# %%
dados_hospedagem_normalizado = pd.json_normalize(dados_hospedagem['info_moveis'])

colunas = list(dados_hospedagem_normalizado.columns)

dados = dados_hospedagem_normalizado.explode(colunas[3:]).reset_index(drop=True)

#dados.drop(columns= 'index', inplace= True) #Outra opção é user o drop

# %%
dados
# Out:
#      avaliacao_geral experiencia_local max_hospedes  \
# 0               10.0                --            1
# 1               10.0                --            1
# 2               10.0                --            1
# 3               10.0                --            1
# 4               10.0                --            1
# ...              ...               ...          ...
# 3813             nan                --            8
# 3814             nan                --            8
# 3815             nan                --            8
# 3816             nan                --            9
# 3817             nan                --            9
#
#                                         descricao_local  \
# 0     This clean and comfortable one bedroom sits ri...
# 1     Our century old Upper Queen Anne house is loca...
# 2     Cozy room in two-bedroom apartment along the l...
# 3     Very lovely and cozy room for one. Convenientl...
# ...
